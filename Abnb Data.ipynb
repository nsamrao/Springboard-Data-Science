# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import *
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
def read_data(location):
    location = location[location['id', 'room_type', 'accommodates', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_value']].convert_objects(convert_numeric=True)
    return location

def get_stats(location):
    x = ['accommodates', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_value']
    location = location.loc[:, x].convert_objects(convert_numeric=True)
    location_stats = location.describe()
    location_stats = concat([location_stats.ix[0:4], location_stats.ix[7:]])
    return location_stats


def reorder(location):
    new = location.set_index('location', append = True).unstack(0)
    return new

# %%
toronto = read_csv('toronto_listings.csv')
x = ['id', 'room_type', 'accommodates','amenities', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']
toronto = toronto.loc[: , x].fillna('')
toronto['price'] = toronto['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
toronto['review_scores_rating'] = toronto['review_scores_cleanliness'].convert_objects(convert_numeric=True)
toronto['review_scores_value'] = toronto['review_scores_value'].convert_objects(convert_numeric=True)


london = read_csv('london.csv')
d = ['id', 'room_type', 'accommodates', 'amenities', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']
london = london.loc[:, d].fillna('')
london['price'] = london['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
london['review_scores_rating'] = london['review_scores_cleanliness'].convert_objects(convert_numeric=True)
london['review_scores_value'] = london['review_scores_value'].convert_objects(convert_numeric=True)

hongkong = read_csv('hongkong.csv')
e = ['id', 'room_type', 'accommodates', 'amenities', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']
hongkong = hongkong.loc[:,e].fillna('')
hongkong['price'] = hongkong['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
hongkong['review_scores_rating'] = hongkong['review_scores_cleanliness'].convert_objects(convert_numeric=True)
hongkong['review_scores_value'] = hongkong['review_scores_value'].convert_objects(convert_numeric=True)

paris = read_csv('paris.csv')
f = ['id', 'room_type', 'accommodates', 'amenities', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']
paris = paris.loc[:,f].fillna('')
paris['price'] = paris['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
paris['review_scores_rating'] = paris['review_scores_cleanliness'].convert_objects(convert_numeric=True)
paris['review_scores_value'] = paris['review_scores_value'].convert_objects(convert_numeric=True)

nyc = read_csv('newyork.csv')
g = ['id', 'room_type', 'accommodates', 'amenities', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']
nyc = nyc.loc[:,g].fillna('')
nyc['price'] = nyc['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
nyc['review_scores_rating'] = nyc['review_scores_cleanliness'].convert_objects(convert_numeric=True)
nyc['review_scores_value'] = nyc['review_scores_value'].convert_objects(convert_numeric=True)

athens = read_csv('athens.csv')
b = ['id','room_type', 'accommodates', 'amenities', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']
athens = athens.loc[:, b].fillna('')
athens['price'] = athens['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
athens['review_scores_rating'] = athens['review_scores_cleanliness'].convert_objects(convert_numeric=True)
athens['review_scores_value'] = athens['review_scores_value'].convert_objects(convert_numeric=True)

berlin = read_csv('berlin.csv')
c = ['id','amenities', 'weekly_price', 'review_scores_rating',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']
berlin = berlin.loc[:, c].fillna('')
berlin['room_type'] = ''
berlin['accommodates'] = ''
berlin['price'] = ''
berlin['minimum_nights'] = ''
berlin['availability_365'] = ''
berlin['availability_365'] = ''
berlin['number_of_reviews'] = ''
berlin['review_scores_accuracy'] = ''
berlin['review_scores_cleanliness'] = ''

# %%
barcelona = read_csv('barcelona.csv')
x = ['id', 'room_type', 'accommodates','amenities', 'price', 'minimum_nights',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']
barcelona = barcelona.loc[: , x].fillna('')
barcelona['price'] = barcelona['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
barcelona['review_scores_rating'] = barcelona['review_scores_cleanliness'].convert_objects(convert_numeric=True)
barcelona['review_scores_value'] = barcelona['review_scores_value'].convert_objects(convert_numeric=True)

edinburgh = read_csv('edinburgh.csv')
edinburgh = edinburgh.loc[: , x].fillna('')
edinburgh['price'] = edinburgh['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
edinburgh['review_scores_rating'] = edinburgh['review_scores_cleanliness'].convert_objects(convert_numeric=True)
edinburgh['review_scores_value'] = edinburgh['review_scores_value'].convert_objects(convert_numeric=True)


edinburgh = read_csv('melbourne.csv')
melbourne = melbourne.loc[: , x].fillna('')
melbourne['price'] = melbourne['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
edinburgh['review_scores_rating'] = edinburgh['review_scores_cleanliness'].convert_objects(convert_numeric=True)
edinburgh['review_scores_value'] = edinburgh['review_scores_value'].convert_objects(convert_numeric=True)


sf = read_csv('sanfran.csv')
sf = sf.loc[: , x].fillna('')
sf['price'] = sf['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
sf['review_scores_rating'] = sf['review_scores_cleanliness'].convert_objects(convert_numeric=True)
sf['review_scores_value'] = sf['review_scores_value'].convert_objects(convert_numeric=True)


madrid = read_csv('madrid.csv')
madrid = madrid.loc[: , x].fillna('')
madrid['price'] = madrid['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
madrid['review_scores_rating'] = madrid['review_scores_cleanliness'].convert_objects(convert_numeric=True)
madrid['review_scores_value'] = madrid['review_scores_value'].convert_objects(convert_numeric=True)


venice = read_csv('venice.csv')
venice = venice.loc[: , x].fillna('')
venice['price'] = venice['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
venice['review_scores_rating'] = venice['review_scores_cleanliness'].convert_objects(convert_numeric=True)
venice['review_scores_value'] = venice['review_scores_value'].convert_objects(convert_numeric=True)

vancouver = read_csv('vancouver.csv')
vancouver = vancouver.loc[: , x].fillna('')
vancouver['price'] = vancouver['price'].map(lambda x: str(x)[1:]).convert_objects(convert_numeric=True)
vancouver['review_scores_rating'] = vancouver['review_scores_cleanliness'].convert_objects(convert_numeric=True)
vancouver['review_scores_value'] = vancouver['review_scores_value'].convert_objects(convert_numeric=True)

# %% [markdown]
# **FIX SYDNEY DATA**
# sydney = read_csv('sydney.csv')
# h = ['id', 'room_type', 'accommodates','amenities', 'price', 'minimum_nights',
#        'availability_365', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value']
# sydney = sydney.loc[:,h].fillna('')
# sydney['price'] = ['price'].map(lambda x: str(x)[1:])

# %%
toronto_st = get_stats(toronto)
toronto_st['location'] = 'Toronto'
toronto_st = reorder(toronto_st)

athens_st = get_stats(athens)
athens_st['location'] = 'Athens'
athens_st = reorder(athens_st)

berlin_st = get_stats(berlin)
berlin_st ['location'] = 'Berlin'
berlin_st = reorder(berlin_st)


london_st = get_stats(london)
london_st['location'] = 'London'
london_st = reorder(london_st)
    
paris_st= get_stats(paris)
paris_st['location'] = 'Paris'
paris_st = reorder(paris_st)

nyc_st = get_stats(nyc)
nyc_st['location'] = 'NYC'
nyc_st= reorder(nyc_st)
   
hongkong_st  = get_stats(hongkong)
hongkong_st['location'] = 'HongKong'
hongkong_st= reorder(hongkong_st)
    
barcelona_st = get_stats(barcelona)
barcelona_st['location'] = 'Barcelona'
barcelona_st = reorder(barcelona_st)

edinburgh_st = get_stats(edinburgh)
edinburgh_st['location'] = 'Edinburgh'
edinburgh_st = reorder(edinburgh_st)

melbourne_st = get_stats(melbourne)
melbourne_st['location'] = 'Melbourne'
melbourne_st = reorder(melbourne_st)

sf_st = get_stats(sf)
sf_st['location'] = 'SanFrancisco'
sf_st= reorder(sf_st)

madrid_st = get_stats(madrid)
madrid_st['location'] = 'Madrid'
madrid_st = reorder(madrid_st)

venice_st = get_stats(venice)
venice_st['location'] = 'Venice'
venice_st= reorder(venice_st)

vancouver_st = get_stats(vancouver)
vancouver_st['location'] = 'Vancouver'
vancouver_st= reorder(vancouver_st)

statistics = toronto_st.append([athens_st, berlin_st, london_st, paris_st, nyc_st, hongkong_st,
                               barcelona_st, edinburgh_st, melbourne_st, sf_st, madrid_st, venice_st, vancouver_st]).fillna('')
statistics
# Out:
#              accommodates                           availability_365       \
#                     count max     mean min      std            count  max
# location
# Toronto             10207  16  2.91996   1  1.76521            10207  365
# Athens               2116  16  3.53403   1  1.93641             2116  365
# Berlin
# London              49348  16  3.04653   1  1.91194            49348  365
# Paris               52725  16  3.05056   1  1.46397            52725  365
# NYC                 39553  16  2.80227   1  1.79219            39553  365
# HongKong             6474  16   3.2439   1  2.44456             6474  365
# Barcelona           14855  16  3.49364   1  2.25903            14855  365
# Edinburgh           12083  16   3.1416   1  2.00564            12083  365
# Melbourne           12083  16   3.1416   1  2.00564            12083  365
# SanFrancisco         8619  16  3.24736   1  2.12421             8619  365
# ...

# %% [markdown]
# **FIX SYDNEY DATA**
# #sydney_st = get_stats(sydney)
# #sydney_st['location'] = 'Sydney'
# #sydney_st = reorder(sydney_st)

# %%
statistics.columns.values
# Out:
# array([('accommodates', 'count'), ('accommodates', 'max'),
#        ('accommodates', 'mean'), ('accommodates', 'min'),
#        ('accommodates', 'std'), ('availability_365', 'count'),
#        ('availability_365', 'max'), ('availability_365', 'mean'),
#        ('availability_365', 'min'), ('availability_365', 'std'),
#        ('minimum_nights', 'count'), ('minimum_nights', 'max'),
#        ('minimum_nights', 'mean'), ('minimum_nights', 'min'),
#        ('minimum_nights', 'std'), ('number_of_reviews', 'count'),
#        ('number_of_reviews', 'max'), ('number_of_reviews', 'mean'),
#        ('number_of_reviews', 'min'), ('number_of_reviews', 'std'),
#        ('price', 'count'), ('price', 'max'), ('price', 'mean'),
#        ('price', 'min'), ('price', 'std'),
#        ('review_scores_accuracy', 'count'),
#        ('review_scores_accuracy', 'max'),
#        ('review_scores_accuracy', 'mean'),
#        ('review_scores_accuracy', 'min'),
#        ('review_scores_accuracy', 'std'),
# ...

# %%
DataFrame(statistics['accommodates']['mean'].convert_objects(convert_numeric=True)).sort(['mean'], ascending=[False])
# Out:
#                   mean
# location
# Venice        3.871483
# Athens        3.534026
# Barcelona     3.493639
# Madrid        3.263631
# SanFrancisco  3.247360
# HongKong      3.243899
# Edinburgh     3.141604
# Melbourne     3.141604
# Paris         3.050564
# London        3.046527
# Vancouver     2.947970
# Toronto       2.919957
# NYC           2.802265
# Berlin             NaN

# %%
DataFrame(statistics['availability_365']['mean'].convert_objects(convert_numeric=True)).sort(['mean'], ascending=[False])
# Out:
#                     mean
# location
# Athens        311.443289
# Barcelona     282.048738
# Venice        278.179348
# Madrid        274.644239
# Vancouver     233.659052
# HongKong      222.105344
# Edinburgh     204.430605
# Melbourne     204.430605
# Toronto       193.382679
# London        185.548817
# Paris         179.460635
# NYC           157.473592
# SanFrancisco  143.499594
# Berlin               NaN

# %%
DataFrame(statistics['price']['mean'].convert_objects(convert_numeric=True)).sort(['mean'], ascending=[False])
# Out:
#                     mean
# location
# HongKong      502.111755
# SanFrancisco  208.376430
# NYC           140.057827
# Venice        132.522254
# Vancouver     124.931977
# Toronto       118.141145
# Paris          95.094939
# London         93.739275
# Barcelona      74.757461
# Madrid         66.200591
# Athens         58.466446
# Melbourne       1.355032
# Berlin               NaN
# Edinburgh            NaN

# %%
x = DataFrame(statistics['review_scores_rating']['mean'].convert_objects(convert_numeric=True))
y = DataFrame(statistics['number_of_reviews']['count'].convert_objects(convert_numeric=True))
z = DataFrame(statistics['number_of_reviews']['mean'].convert_objects(convert_numeric=True))
a = DataFrame(statistics['review_scores_value']['mean'].convert_objects(convert_numeric=True))
b = DataFrame(statistics['review_scores_accuracy']['mean'].convert_objects(convert_numeric=True))


df = concat([x,y,z,a,b], axis = 1)
df.columns=['Mean Review Score', 'Count of Reviews', 'Mean # of Reviews', 'Mean Value Review', 'Mean Accuracy Review']
df.fillna('').sort(['Mean Review Score'], ascending=[False])
# Out:
#               Mean Review Score Count of Reviews Mean # of Reviews  \
# location
# Melbourne             93.130369            12083           12.3337
# Berlin                92.276878
# SanFrancisco           9.413716             8619           19.6934
# Edinburgh              9.380483            12083           12.3337
# Vancouver              9.364658             4728           12.9681
# Athens                 9.361499             2116           16.3847
# Toronto                9.313840            10207           11.0871
# Venice                 9.276074             3128           22.3302
# Madrid                 9.181786             7446           14.3969
# London                 9.150406            49348           11.4351
# NYC                    9.131806            39553           14.5317
# Paris                  9.109395            52725            12.586
# Barcelona              9.033653            14855            15.623
# ...

# %% [markdown]
# Lets look at interesting relationship between price and average values of different features for each city.

# %%
x = statistics['availability_365']['mean'].convert_objects(convert_numeric=True)
y = statistics['price']['mean'].convert_objects(convert_numeric=True)

# %%
x = statistics['availability_365']['mean'].convert_objects(convert_numeric=True)
statistics['price']['mean'].convert_objects(convert_numeric=True)

n = (x.reset_index()).location.tolist()

fig, ax = plt.subplots()
ax.scatter(x, y, c=y,cmap ='plasma', s =200)

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i],y[i]), fontsize = 10)
    
    
plt.xlabel('Availibility out of last 365 days', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.title('Price and Availibility', fontsize=14, fontweight='bold')

# %%
x = statistics['review_scores_rating']['mean'].convert_objects(convert_numeric=True)
y = statistics['price']['mean'].convert_objects(convert_numeric=True)

# %%
n = (x.reset_index()).location.tolist()

fig, ax = plt.subplots()
ax.scatter(x, y, c=y,cmap ='plasma', s =200)

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i],y[i]), fontsize = 10)
    
    
plt.xlabel('Average Rating', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.title('Price and Average Rating', fontsize=14, fontweight='bold')

# %%
x = statistics['review_scores_accuracy']['mean'].convert_objects(convert_numeric=True)
y = statistics['price']['mean'].convert_objects(convert_numeric=True)

# %%
x = statistics['availability_365']['mean'].convert_objects(convert_numeric=True)
statistics['price']['mean'].convert_objects(convert_numeric=True)

n = (x.reset_index()).location.tolist()

fig, ax = plt.subplots()
ax.scatter(x, y, c=y,cmap ='plasma', s =200)

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i],y[i]), fontsize = 10)
    
    
plt.xlabel('Availibility out of last 365 days', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.title('Price and Availibility', fontsize=14, fontweight='bold')

# %%
x = statistics['review_scores_accuracy']['mean'].convert_objects(convert_numeric=True)
y = statistics['price']['mean'].convert_objects(convert_numeric=True)

# %%
n = (x.reset_index()).location.tolist()

fig, ax = plt.subplots()
ax.scatter(x, y, c=y,cmap ='plasma', s =200)

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i],y[i]), fontsize = 10)
    
    
plt.xlabel('Availibility out of last 365 days', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.title('Price and Availibility', fontsize=14, fontweight='bold')

# %%
x = statistics['review_scores_value']['mean'].convert_objects(convert_numeric=True)
y = statistics['price']['mean'].convert_objects(convert_numeric=True)

# %%
n = (x.reset_index()).location.tolist()

fig, ax = plt.subplots()
ax.scatter(x, y, c=y,cmap ='plasma', s =200)

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i],y[i]), fontsize = 10)
    
    
plt.xlabel('Average Value Rating', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.title('Average Value Rating and Price', fontsize=14, fontweight='bold')

# %%
x = statistics['number_of_reviews']['count'].convert_objects(convert_numeric=True).plot(kind ='bar')
plt.xlabel('Location', fontsize=14)
plt.ylabel('Count of Reviews', fontsize=14)
plt.title('# of Reviews per City', fontsize=14, fontweight='bold')

# %% [markdown]
# **Using the scatter_matrix function in Pandas next, we can quickly show a matrix of each feature as a function of another, checking for any collinearity among the features. The cells along the diagonal of this matrix contain a histogram, with the values shown along the X axis. Collinearity in this case is less likely because we've picked a small set of features that are not obviously related to each other, but it's a good thing to check anyway to see if we have anything that will throw things off.**

# %%
scattercols = ['accommodates', 'price',
       'availability_365', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']


axs = scatter_matrix(toronto[scattercols],figsize=(12, 12), c='red')
